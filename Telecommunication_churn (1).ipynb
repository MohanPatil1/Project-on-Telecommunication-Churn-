# %%
# Import required Liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\Mohan Patil\OneDrive\Desktop\Datasets\Churn (1).csv",index_col='Unnamed: 0')
df
# Out:
#      state      area.code  account.length voice.plan  voice.messages  \
# 1       KS  area_code_415             128        yes              25
# 2       OH  area_code_415             107        yes              26
# 3       NJ  area_code_415             137         no               0
# 4       OH  area_code_408              84         no               0
# 5       OK  area_code_415              75         no               0
# ...    ...            ...             ...        ...             ...
# 4996    HI  area_code_408              50        yes              40
# 4997    WV  area_code_415             152         no               0
# 4998    DC  area_code_415              61         no               0
# 4999    DC  area_code_510             109         no               0
# 5000    VT  area_code_415              86        yes              34
#
#      intl.plan  intl.mins  intl.calls  intl.charge  day.mins  day.calls  \
# ...

# %%
df.drop(["area.code"],inplace=True,axis=1)
df.drop(["state"],inplace=True,axis=1)
df
# Out:
#       account.length voice.plan  voice.messages intl.plan  intl.mins  \
# 1                128        yes              25        no       10.0
# 2                107        yes              26        no       13.7
# 3                137         no               0        no       12.2
# 4                 84         no               0       yes        6.6
# 5                 75         no               0       yes       10.1
# ...              ...        ...             ...       ...        ...
# 4996              50        yes              40        no        9.9
# 4997             152         no               0        no       14.7
# 4998              61         no               0        no       13.6
# 4999             109         no               0        no        8.5
# 5000              86        yes              34        no        9.3
#
#       intl.calls  intl.charge  day.mins  day.calls day.charge eve.mins  \
# ...

# %% [markdown]
# ## Exploratory Data Analsis (EDA)
# ### Data Preprocessing

# %%
df.shape
# Out:
# (5000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 1 to 5000
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account.length  5000 non-null   int64
#  1   voice.plan      5000 non-null   object
#  2   voice.messages  5000 non-null   int64
#  3   intl.plan       5000 non-null   object
#  4   intl.mins       5000 non-null   float64
#  5   intl.calls      5000 non-null   int64
#  6   intl.charge     5000 non-null   float64
#  7   day.mins        5000 non-null   float64
#  8   day.calls       5000 non-null   int64
#  9   day.charge      5000 non-null   object
#  10  eve.mins        5000 non-null   object
#  11  eve.calls       5000 non-null   int64
#  12  eve.charge      5000 non-null   float64
#  13  night.mins      5000 non-null   float64
#  14  night.calls     5000 non-null   int64
#  15  night.charge    5000 non-null   float64
#  16  customer.calls  5000 non-null   int64
# ...

# %%
df.head()
# Out:
#    account.length voice.plan  voice.messages intl.plan  intl.mins  intl.calls  \
# 1             128        yes              25        no       10.0           3
# 2             107        yes              26        no       13.7           3
# 3             137         no               0        no       12.2           5
# 4              84         no               0       yes        6.6           7
# 5              75         no               0       yes       10.1           3
#
#    intl.charge  day.mins  day.calls day.charge eve.mins  eve.calls  \
# 1         2.70     265.1        110      45.07    197.4         99
# 2         3.70     161.6        123      27.47    195.5        103
# 3         3.29     243.4        114      41.38    121.2        110
# 4         1.78     299.4         71       50.9     61.9         88
# 5         2.73     166.7        113      28.34    148.3        122
#
#    eve.charge  night.mins  night.calls  night.charge  customer.calls churn
# ...

# %%
# Check for null Values
df.isnull().sum()
# Out:
# account.length    0
# voice.plan        0
# voice.messages    0
# intl.plan         0
# intl.mins         0
# intl.calls        0
# intl.charge       0
# day.mins          0
# day.calls         0
# day.charge        0
# eve.mins          0
# eve.calls         0
# eve.charge        0
# night.mins        0
# night.calls       0
# night.charge      0
# customer.calls    0
# churn             0
# dtype: int64

# %%
# Convert column to float beforing removing Nan value
column_convert = ['day.charge','eve.mins']
df[column_convert] = df[column_convert].astype(float)

# %%
non_numeric_value = pd.to_numeric(df['day.charge'],errors='coerce').isnull().sum()
print(non_numeric_value)
# Out:
# 7

# %%
column_mean = pd.to_numeric(df['day.charge'],errors='coerce').mean()
df['day.charge'].fillna(column_mean,inplace=True) # Replacing the Nan Value with mean

# %%
non_numeric_value1 = pd.to_numeric(df['eve.mins'],errors='coerce').isnull().sum()
print(non_numeric_value1)
# Out:
# 24

# %%
column_mean = pd.to_numeric(df['eve.mins'],errors='coerce').mean()
df['eve.mins'].fillna(column_mean,inplace=True) # Replacing the Nan Value with mean

# %%
df.head()
# Out:
#    account.length voice.plan  voice.messages intl.plan  intl.mins  intl.calls  \
# 1             128        yes              25        no       10.0           3
# 2             107        yes              26        no       13.7           3
# 3             137         no               0        no       12.2           5
# 4              84         no               0       yes        6.6           7
# 5              75         no               0       yes       10.1           3
#
#    intl.charge  day.mins  day.calls  day.charge  eve.mins  eve.calls  \
# 1         2.70     265.1        110       45.07     197.4         99
# 2         3.70     161.6        123       27.47     195.5        103
# 3         3.29     243.4        114       41.38     121.2        110
# 4         1.78     299.4         71       50.90      61.9         88
# 5         2.73     166.7        113       28.34     148.3        122
#
#    eve.charge  night.mins  night.calls  night.charge  customer.calls churn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 1 to 5000
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account.length  5000 non-null   int64
#  1   voice.plan      5000 non-null   object
#  2   voice.messages  5000 non-null   int64
#  3   intl.plan       5000 non-null   object
#  4   intl.mins       5000 non-null   float64
#  5   intl.calls      5000 non-null   int64
#  6   intl.charge     5000 non-null   float64
#  7   day.mins        5000 non-null   float64
#  8   day.calls       5000 non-null   int64
#  9   day.charge      5000 non-null   float64
#  10  eve.mins        5000 non-null   float64
#  11  eve.calls       5000 non-null   int64
#  12  eve.charge      5000 non-null   float64
#  13  night.mins      5000 non-null   float64
#  14  night.calls     5000 non-null   int64
#  15  night.charge    5000 non-null   float64
#  16  customer.calls  5000 non-null   int64
# ...

# %%
# Print Unique Values
print(df.nunique())
# Out:
# account.length     218
# voice.plan           2
# voice.messages      48
# intl.plan            2
# intl.mins          170
# intl.calls          21
# intl.charge        170
# day.mins          1961
# day.calls          123
# day.charge        1962
# eve.mins          1877
# eve.calls          126
# eve.charge        1659
# night.mins        1853
# night.calls        131
# night.charge      1028
# customer.calls      10
# churn                2
# dtype: int64

# %%
# To Convert Categorical class column in to Binary 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['voice.plan']=le.fit_transform(df['voice.plan'])
df['intl.plan']= le.fit_transform(df['intl.plan'])
df['churn']=le.fit_transform(df['churn'])

# %%
# Changing Column Name 
df1 = df.rename(columns={'account.length':'account_length','voice.plan':'voice_plan','voice.messages':'voice_messages','intl.plan':'international_plan',
                  'intl.mins':'international_mins','intl.calls':'international_calls','intl.charge':'international_charge',
                  'day.mins':'day_mins','day.calls':'day_calls','day.charge':'day_charge','eve.mins':'evening_mins','eve.calls':'evening_calls',
                  'eve.charge':'evening_charge','night.mins':'night_mins','night.calls':'night_calls','night.charge':'night_charge','customer.calls':'customer_calls'})

# %%
df1.describe()
# Out:
#        account_length   voice_plan  voice_messages  international_plan  \
# count      5000.00000  5000.000000     5000.000000         5000.000000
# mean        100.25860     0.264600        7.755200            0.094600
# std          39.69456     0.441164       13.546393            0.292691
# min           1.00000     0.000000        0.000000            0.000000
# 25%          73.00000     0.000000        0.000000            0.000000
# 50%         100.00000     0.000000        0.000000            0.000000
# 75%         127.00000     1.000000       17.000000            0.000000
# max         243.00000     1.000000       52.000000            1.000000
#
#        international_mins  international_calls  international_charge  \
# count         5000.000000          5000.000000           5000.000000
# mean            10.261780             4.435200              2.771196
# std              2.761396             2.456788              0.745514
# ...

# %%
# Checking correlation between different columns
df1.corr()
# Out:
#                       account_length  voice_plan  voice_messages  \
# account_length              1.000000   -0.006650       -0.014575
# voice_plan                 -0.006650    1.000000        0.954508
# voice_messages             -0.014575    0.954508        1.000000
# international_plan          0.014681    0.009054        0.011947
# international_mins          0.001291    0.004116        0.002463
# international_calls         0.014277   -0.007525        0.000124
# international_charge        0.001292    0.004165        0.002505
# day_mins                   -0.001017    0.002059        0.005381
# day_calls                   0.028240   -0.001735        0.000883
# day_charge                 -0.000799    0.001805        0.005138
# evening_mins               -0.008688    0.022978        0.018862
# evening_calls               0.009143   -0.005916       -0.003954
# evening_charge             -0.009587    0.023332        0.019496
# ...

# %%
df_corr = df1.corr()
fig,ax = plt.subplots(figsize=(18,16))
sns.heatmap(df_corr,annot=True,linewidths=.5 ,cmap='coolwarm')

print(df_corr['churn'])
# Out:
# account_length          0.021203
# voice_plan             -0.110698
# voice_messages         -0.097633
# international_plan      0.259123
# international_mins      0.063285
# international_calls    -0.046893
# international_charge    0.063275
# day_mins                0.207705
# day_calls               0.016130
# day_charge              0.207578
# evening_mins            0.089180
# evening_calls          -0.006284
# evening_charge          0.089282
# night_mins              0.045677
# night_calls            -0.006986
# night_charge            0.045673
# customer_calls          0.212564
# churn                   1.000000
# Name: churn, dtype: float64

# %%
df1.drop_duplicates(inplace=True)
df1.shape
# Out:
# (5000, 18)

# %% [markdown]
# - There is No Duplicate value in the dataset

# %% [markdown]
# ##                                            Target Column Analysis

# %%
# Unique Values
df1['churn'].unique()
# Out:
# array([0, 1])

# %%
# Count of Classes
df1['churn'].value_counts()
# Out:
# 0    4293
# 1     707
# Name: churn, dtype: int64

# %%
plt.pie(df1['churn'].value_counts(),startangle=90,labels=df['churn'].unique(),autopct='%1.1f%%',explode=[0,0.9],shadow=True)
plt.title('Proportional distribution of Churn', fontsize=16)
plt.axis('equal') ;

# %%
sns.countplot(x='churn',data=df1)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# ## Data Visualization

# %%
#Boxplot Visualization
numeric_features = ["account_length", "international_mins", "day_mins", "night_mins"]
for feature in numeric_features:
    sns.boxplot(data=df1, x='churn', y=feature ,hue="churn")
    plt.title(f"Distribution of {feature}")
    plt.show()

# %%
# Checking distribution 
plt.figure(figsize=(6,6))
sns.histplot(data=df1,x='account_length')
# Out:
# <AxesSubplot:xlabel='account_length', ylabel='Count'>

# %%
plt.figure(figsize=(6,6))
sns.histplot(data=df1,x='day_mins')
# Out:
# <AxesSubplot:xlabel='day_mins', ylabel='Count'>

# %%
plt.figure(figsize=(6,6))
sns.histplot(data=df1,x='day_charge')
# Out:
# <AxesSubplot:xlabel='day_charge', ylabel='Count'>

# %%
ax = sns.distplot(df1['account_length'],hist=True,kde=False,bins=int(180/5),color='darkblue',
                 hist_kws={'edgecolor':'black'},
                 kde_kws={'linewidth':4})
ax.set_ylabel('churn')
ax.set_xlabel('account_length')
ax.set_title('churn rate by account length')
# Out:
# Text(0.5, 1.0, 'churn rate by account length')

# %% [markdown]
# ## Ploting distribution of Mins

# %%
fig, ax = plt.subplots(2,2)

plt.setp(ax[0,0],xlabel = 'Day vs Evening')
sns.distplot(x = df1['evening_mins'], ax=ax[0,0], color = '#e71d36')
sns.distplot(x = df1['day_mins'], ax=ax[0,0], color = '#ff9f1c')

plt.setp(ax[0,1],xlabel = 'Day vs Night')
sns.distplot(x = df1['night_mins'], ax=ax[0,1], color = '#2ec4b6')
sns.distplot(x = df1['day_mins'], ax=ax[0,1], color = '#ff9f1c')

plt.setp(ax[1,0],xlabel = 'Night vs Evening')
sns.distplot(x = df1['night_mins'], ax=ax[1,0], color = '#2ec4b6')
sns.distplot(x = df1['evening_mins'], ax=ax[1,0], color = '#e71d36')

sns.distplot(df1['international_mins'], ax=ax[1,1], color = '#78290f')

plt.tight_layout()

# %% [markdown]
# ## PLoting distribution of calls

# %%
fig, ax = plt.subplots(2,2)

plt.setp(ax[0,0],xlabel = 'Day calls vs Evening calls')
sns.distplot(x = df1['evening_calls'], ax=ax[0,0], color = '#e71d36')
sns.distplot(x = df1['day_calls'], ax=ax[0,0], color = '#ff9f1c')

plt.setp(ax[0,1],xlabel = 'Day calls vs Night calls')
sns.distplot(x = df1['night_calls'], ax=ax[0,1], color = '#2ec4b6')
sns.distplot(x = df1['day_calls'], ax=ax[0,1], color = '#ff9f1c')

plt.setp(ax[1,0],xlabel = 'Night calls vs Evening calls')
sns.distplot(x = df1['night_calls'], ax=ax[1,0], color = '#2ec4b6')
sns.distplot(x = df1['evening_calls'], ax=ax[1,0], color = '#e71d36')

sns.distplot(df1['international_calls'], ax=ax[1,1], color = '#78290f')

plt.tight_layout()

# %% [markdown]
# ## Ploting Distribution of charge

# %%
fig, ax = plt.subplots(2,2)

plt.setp(ax[0,0],xlabel = 'Day charge vs Evening charge')
sns.distplot(x = df1['evening_charge'], ax=ax[0,0], color = '#e71d36')
sns.distplot(x = df1['day_charge'], ax=ax[0,0], color = '#ff9f1c')

plt.setp(ax[0,1],xlabel = 'Day charge vs Night charge')
sns.distplot(x = df1['night_charge'], ax=ax[0,1], color = '#2ec4b6')
sns.distplot(x = df1['day_charge'], ax=ax[0,1], color = '#ff9f1c')

plt.setp(ax[1,0],xlabel = 'Night charge vs Evening charge')
sns.distplot(x = df1['night_charge'], ax=ax[1,0], color = '#2ec4b6')
sns.distplot(x = df1['evening_charge'], ax=ax[1,0], color = '#e71d36')

sns.distplot(df1['international_charge'], ax=ax[1,1], color = '#78290f')

plt.tight_layout()

# %%
col = ['day_charge','international_charge','evening_charge','night_charge','churn']
df_1 = df1[col]
df_1
# Out:
#       day_charge  international_charge  evening_charge  night_charge  churn
# 1          45.07                  2.70           16.78         11.01      0
# 2          27.47                  3.70           16.62         11.45      0
# 3          41.38                  3.29           10.30          7.32      0
# 4          50.90                  1.78            5.26          8.86      0
# 5          28.34                  2.73           12.61          8.41      0
# ...          ...                   ...             ...           ...    ...
# 4996       40.07                  2.67           18.96         13.39      0
# 4997       31.31                  3.97           21.83          9.61      1
# 4998       23.90                  3.67           14.69          9.56      0
# 4999       32.10                  2.30           14.59         10.10      0
# 5000       22.00                  2.51           22.70          6.97      0
#
# [5000 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df_1,hue="churn")

# %%
# Correlation between minutes and charge
print(df1.international_mins.corr(df1.international_charge))
plt.scatter(df1.international_mins,df1.international_charge,c='magenta')
# Out:
# 0.999992657020837

# %%
print(df1.day_mins.corr(df1.day_charge))
plt.scatter(df1.day_mins,df1.day_charge,c='magenta')
# Out:
# 0.9997670198014301

# %%
print(df1.evening_mins.corr(df1.evening_charge))
plt.scatter(df1.evening_mins,df1.evening_charge,c='magenta')
# Out:
# 0.9976622029295762

# %%
print(df1.night_mins.corr(df1.night_charge))
plt.scatter(df1.night_mins,df1.night_charge,c='magenta')
# Out:
# 0.9999992071867975

# %% [markdown]
# #                                                       Key Insights

# %% [markdown]
# 1) Data is imbalanced where Major class : 'Not churn'(class:0) and Minor class : 'churn'(class:1)
#
# 2) Minutes and Charge have almost perfect positive correlation between them.
#
# 3) Dataset have 'Nan' value and thos value replace with 'mean' and dataset not having duplicate value also outliers are present which need to treated.

# %% [markdown]
# ### Outlier Detection Using Isolation Forest

# %%
# from sklearn.ensemble import IsolationForest

# clf = IsolationForest(random_state=10,contamination=0.05)

# clf.fit(df1)

# pred_outliers = clf.predict(df1)

# pred_outliers

# %%
# # Filter out the outliers from the dataset
# X_filter = df1[pred_outliers == 1]

# %%
# outlier_percentages = (pred_outliers == -1).sum() / len(df1) * 100
# print(outlier_percentages)

# %%
# plt.figure(figsize=(15,10))
# sns.boxplot(data=X_filter)

# plt.show()

# %%
df1.columns
# Out:
# Index(['account_length', 'voice_plan', 'voice_messages', 'international_plan',
#        'international_mins', 'international_calls', 'international_charge',
#        'day_mins', 'day_calls', 'day_charge', 'evening_mins', 'evening_calls',
#        'evening_charge', 'night_mins', 'night_calls', 'night_charge',
#        'customer_calls', 'churn'],
#       dtype='object')

# %%
# Considering columns whose outliers need to be treated
req_col = ['account_length','voice_messages','international_calls','day_mins', 'evening_mins', 'night_mins', 'international_mins', 'day_calls', 'day_charge', 'evening_calls', 
           'international_charge','evening_charge', 'night_calls', 'night_charge','customer_calls']

# %%
# Calculate quartile And IQR 
q1 = np.percentile(df1[req_col],25)
q3 = np.percentile(df1[req_col],75)
iqr = q3 - q1

# Get Lower and upper bound
upper = q3+1.5*iqr 
lower = q1-1.5*iqr

outlier = ((df1[req_col]<lower) | (df1[req_col]>upper))

# Get the indices of outlier rows
outlier_indices = np.where(outlier)[0]

print("Total No. of Outlier:",len(outlier_indices))
print("\n","Outlier Indices :",outlier_indices)
# Out:
# Total No. of Outlier: 711
#
#  Outlier Indices : [   3    6    8    9   14   15   15   16   32   42   42   52   70   76
#    80   85  106  117  149  151  155  156  179  180  194  197  198  201
#   229  230  244  247  265  283  284  287  289  289  290  299  302  302
#   303  307  315  320  330  337  360  363  365  378  383  386  389  415
#   419  422  431  434  436  438  444  447  461  473  475  478  487  497
#   507  507  516  529  534  535  552  556  559  561  568  571  575  579
#   580  583  584  590  605  606  611  616  617  619  629  632  634  656
#   660  661  679  688  698  711  726  731  732  759  763  782  784  790
#   791  802  803  815  815  827  832  838  845  846  862  871  873  876
#   878  881  882  901  911  913  913  914  914  916  917  918  922  932
#   939  941  957  961  975  984  985  990 1006 1011 1014 1025 1026 1045
#  1078 1081 1112 1113 1123 1161 1163 1165 1165 1182 1188 1192 1197 1202
#  1238 1254 1255 1270 1275 1276 1282 1291 1298 1317 1334 1344 1350 1355
# ...

# %%
# Reset the index the dataframe
df_reset_index = df1.reset_index(drop=True)
# Remove row with outlier indices
df_clean = df_reset_index.drop(outlier_indices)
# print the modified dataframe
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4321 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   account_length        4321 non-null   int64
#  1   voice_plan            4321 non-null   int32
#  2   voice_messages        4321 non-null   int64
#  3   international_plan    4321 non-null   int32
#  4   international_mins    4321 non-null   float64
#  5   international_calls   4321 non-null   int64
#  6   international_charge  4321 non-null   float64
#  7   day_mins              4321 non-null   float64
#  8   day_calls             4321 non-null   int64
#  9   day_charge            4321 non-null   float64
#  10  evening_mins          4321 non-null   float64
#  11  evening_calls         4321 non-null   int64
#  12  evening_charge        4321 non-null   float64
#  13  night_mins            4321 non-null   float64
#  14  night_calls           4321 non-null   int64
# ...

# %%
df_clean.shape
# Out:
# (4321, 18)

# %% [markdown]
# # Feature Engineering

# %%
# Feature Selection - Univariate Feature Selection 
data = df_clean.drop(['churn'],axis=1)

from sklearn.feature_selection import SelectKBest,f_classif
select = SelectKBest(score_func=f_classif,k=9)

data_req = select.fit_transform(data,df_clean['churn'])
data_req
# Out:
# array([[  1.  ,   0.  ,  10.  , ..., 197.4 ,  16.78,   1.  ],
#        [  1.  ,   0.  ,  13.7 , ..., 195.5 ,  16.62,   1.  ],
#        [  0.  ,   0.  ,  12.2 , ..., 121.2 ,  10.3 ,   0.  ],
#        ...,
#        [  0.  ,   0.  ,  13.6 , ..., 172.8 ,  14.69,   1.  ],
#        [  0.  ,   0.  ,   8.5 , ..., 171.7 ,  14.59,   0.  ],
#        [  1.  ,   0.  ,   9.3 , ..., 267.1 ,  22.7 ,   0.  ]])

# %%
dfscores = pd.DataFrame(select.scores_)
dfcolumns = pd.DataFrame(data.columns)

# %%
featurescores = pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns=['features','scores']
featurescores
# Out:
#                 features      scores
# 0         account_length    1.017519
# 1             voice_plan   22.000502
# 2         voice_messages   14.898735
# 3     international_plan  380.893902
# 4     international_mins   25.964048
# 5    international_calls   10.771407
# 6   international_charge   25.934518
# 7               day_mins   29.935459
# 8              day_calls    1.770341
# 9             day_charge   29.806131
# 10          evening_mins   15.634381
# 11         evening_calls    0.114373
# 12        evening_charge   15.876128
# 13            night_mins    5.580924
# 14           night_calls    0.509233
# 15          night_charge    5.578936
# 16        customer_calls  295.992501

# %%
df_new = pd.DataFrame(select.inverse_transform(data_req),index=df_clean.index,columns=data.columns)

req_columns = df_new.columns[df_new.var()!=0]
df_final = df_new[req_columns]
df_final.head()
# Out:
#    voice_plan  international_plan  international_mins  international_charge  \
# 0         1.0                 0.0                10.0                  2.70
# 1         1.0                 0.0                13.7                  3.70
# 2         0.0                 0.0                12.2                  3.29
# 4         0.0                 1.0                10.1                  2.73
# 5         0.0                 1.0                 6.3                  1.70
#
#    day_mins  day_charge  evening_mins  evening_charge  customer_calls
# 0     265.1       45.07         197.4           16.78             1.0
# 1     161.6       27.47         195.5           16.62             1.0
# 2     243.4       41.38         121.2           10.30             0.0
# 4     166.7       28.34         148.3           12.61             3.0
# 5     223.4       37.98         220.6           18.75             0.0

# %%
df_target = df_clean['churn']
Final_df = pd.concat([df_final,df_target],axis=1)
Final_df.head()
# Out:
#    voice_plan  international_plan  international_mins  international_charge  \
# 0         1.0                 0.0                10.0                  2.70
# 1         1.0                 0.0                13.7                  3.70
# 2         0.0                 0.0                12.2                  3.29
# 4         0.0                 1.0                10.1                  2.73
# 5         0.0                 1.0                 6.3                  1.70
#
#    day_mins  day_charge  evening_mins  evening_charge  customer_calls  churn
# 0     265.1       45.07         197.4           16.78             1.0      0
# 1     161.6       27.47         195.5           16.62             1.0      0
# 2     243.4       41.38         121.2           10.30             0.0      0
# 4     166.7       28.34         148.3           12.61             3.0      0
# 5     223.4       37.98         220.6           18.75             0.0      0

# %%
print(Final_df.shape)
Final_df.corr()
# Out:
# (4321, 10)
#                       voice_plan  international_plan  international_mins  \
# voice_plan              1.000000            0.009675            0.002709
# international_plan      0.009675            1.000000            0.035818
# international_mins      0.002709            0.035818            1.000000
# international_charge    0.002748            0.035746            0.999993
# day_mins                0.012350            0.032676           -0.020500
# day_charge              0.012037            0.032521           -0.020246
# evening_mins            0.021448            0.004396            0.011652
# evening_charge          0.020996            0.006897            0.012283
# customer_calls         -0.012588           -0.012649           -0.014945
# churn                  -0.071190            0.284681            0.077302
#
#                       international_charge  day_mins  day_charge  \
# voice_plan                        0.002748  0.012350    0.012037
# ...

# %%
Final_df.describe()
# Out:
#         voice_plan  international_plan  international_mins  \
# count  4321.000000         4321.000000         4321.000000
# mean      0.266605            0.092571           10.270678
# std       0.442235            0.289864            2.758645
# min       0.000000            0.000000            0.000000
# 25%       0.000000            0.000000            8.500000
# 50%       0.000000            0.000000           10.300000
# 75%       1.000000            0.000000           12.000000
# max       1.000000            1.000000           20.000000
#
#        international_charge     day_mins   day_charge  evening_mins  \
# count           4321.000000  4321.000000  4321.000000   4321.000000
# mean               2.773585   176.338533    29.982540    194.601524
# std                0.744738    50.098874     8.514469     45.060847
# min                0.000000     0.000000     0.000000      0.000000
# 25%                2.300000   142.300000    24.230000    164.300000
# ...

# %%
Final_df.columns
# Out:
# Index(['voice_plan', 'international_plan', 'international_mins',
#        'international_charge', 'day_mins', 'day_charge', 'evening_mins',
#        'evening_charge', 'customer_calls', 'churn'],
#       dtype='object')

# %% [markdown]
# ## Feature Selection Using Feature importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
fi = model.fit(data,df_clean['churn'])
fi
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.03908359 0.01273731 0.01425538 0.0904112  0.05356141 0.06357231
#  0.05590542 0.09289245 0.03991551 0.09152144 0.06097543 0.03808557
#  0.06084048 0.04312946 0.03827858 0.0454076  0.15942685]

# %%
# Plot graph for feature importance to get better visualization
feat_importance = pd.Series(model.feature_importances_,index=data.columns)
feat_importance.nlargest(9).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Select the top 9 features based on importance scores
top_features = feat_importance.nlargest(9).index

# Create a new DataFrame with the top features
data_top_features = data[top_features]

# Print the top features
data_top_features.head()
# Out:
#    customer_calls  day_mins  day_charge  international_plan  \
# 0               1     265.1       45.07                   0
# 1               1     161.6       27.47                   0
# 2               0     243.4       41.38                   0
# 4               3     166.7       28.34                   1
# 5               0     223.4       37.98                   1
#
#    international_calls  evening_mins  evening_charge  international_charge  \
# 0                    3         197.4           16.78                  2.70
# 1                    3         195.5           16.62                  3.70
# 2                    5         121.2           10.30                  3.29
# 4                    3         148.3           12.61                  2.73
# 5                    6         220.6           18.75                  1.70
#
#    international_mins
# 0                10.0
# 1                13.7
# 2                12.2
# 4                10.1
# 5                 6.3

# %%
target = df_clean['churn']
Final_df_fi = pd.concat([data_top_features,target],axis=1)
Final_df_fi.head()
# Out:
#    customer_calls  day_mins  day_charge  international_plan  \
# 0               1     265.1       45.07                   0
# 1               1     161.6       27.47                   0
# 2               0     243.4       41.38                   0
# 4               3     166.7       28.34                   1
# 5               0     223.4       37.98                   1
#
#    international_calls  evening_mins  evening_charge  international_charge  \
# 0                    3         197.4           16.78                  2.70
# 1                    3         195.5           16.62                  3.70
# 2                    5         121.2           10.30                  3.29
# 4                    3         148.3           12.61                  2.73
# 5                    6         220.6           18.75                  1.70
#
#    international_mins  churn
# 0                10.0      0
# 1                13.7      0
# 2                12.2      0
# 4                10.1      0
# ...

# %%
Final_df_fi.shape
# Out:
# (4321, 10)

# %%
Final_df_fi.corr()
# Out:
#                       customer_calls  day_mins  day_charge  \
# customer_calls              1.000000  0.006854    0.007097
# day_mins                    0.006854  1.000000    0.999688
# day_charge                  0.007097  0.999688    1.000000
# international_plan         -0.012649  0.032676    0.032521
# international_calls        -0.019220 -0.013630   -0.014003
# evening_mins                0.005754 -0.006659   -0.007466
# evening_charge              0.004330 -0.006595   -0.007399
# international_charge       -0.014994 -0.020455   -0.020202
# international_mins         -0.014945 -0.020500   -0.020246
# churn                       0.253253  0.082966    0.082788
#
#                       international_plan  international_calls  evening_mins  \
# customer_calls                 -0.012649            -0.019220      0.005754
# day_mins                        0.032676            -0.013630     -0.006659
# day_charge                      0.032521            -0.014003     -0.007466
# ...

# %% [markdown]
# # Dimensionality Reduction using Principal component Analysis(PCA)
# ###  To Eliminate the problem of multi-colinearity

# %%
# import packages for PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
# Convert data to array
Data = data.values
Data

# Standardization the data
Data_std = scale(Data)

# %%
# Initiate PCA Algorithmn
pca = PCA(n_components=17)
pca_values = pca.fit_transform(Data_std)
pca_values
# Out:
# array([[-1.48838925e+00, -1.67769861e+00,  1.90189037e+00, ...,
#          9.40032485e-04,  6.66200990e-04,  5.29077769e-04],
#        [ 9.79828266e-01,  5.86649355e-01,  1.90533826e+00, ...,
#          2.30705472e-04, -4.40020934e-04, -6.49625034e-04],
#        [-1.18207473e+00, -4.11781677e-01, -2.59703305e+00, ...,
#         -1.22326802e-03,  4.24385530e-03, -1.00171264e-03],
#        ...,
#        [ 1.01678742e+00,  1.69113535e+00, -5.93176410e-01, ...,
#         -9.56109359e-04,  2.17118131e-03, -5.74703873e-04],
#        [-1.40515590e+00,  7.82091707e-01,  1.10264077e-01, ...,
#         -2.30647122e-04, -4.18383922e-03, -6.38662322e-04],
#        [ 2.19556395e+00, -1.69258011e+00,  1.62985888e+00, ...,
#          1.99582788e-03,  1.85675974e-03, -1.26182622e-03]])

# %%
# Weights of components from w1 to w17
pca.components_
# Out:
# array([[-2.13649101e-02,  5.83284728e-02,  5.53703030e-02,
#          2.85187090e-02,  4.73459189e-01,  4.60649241e-02,
#          4.73452988e-01, -3.18118072e-01, -6.77523741e-03,
#         -3.18196739e-01,  3.61556778e-01, -1.42741609e-02,
#          3.62010719e-01, -1.96123791e-01, -1.77835754e-02,
#         -1.96118168e-01, -1.01342797e-02],
#        [ 2.16862828e-02, -2.82261155e-01, -2.85528933e-01,
#         -5.38580292e-02,  7.22078617e-02, -1.15483308e-02,
#          7.21883198e-02, -4.64551130e-01,  4.03341192e-03,
#         -4.64448780e-01, -2.60845342e-01, -1.47494740e-02,
#         -2.61024659e-01,  3.58140290e-01,  1.10693988e-02,
#          3.58155920e-01, -1.67729030e-02],
#        [-7.92995397e-03,  3.16814447e-01,  3.15158239e-01,
#         -3.24653826e-02, -1.49355097e-01, -1.18927632e-02,
#         -1.49304013e-01, -4.67005738e-02, -3.06280051e-02,
#         -4.74218395e-02,  3.70708958e-01,  3.15328078e-03,
# ...

# %%
# Understanding variance of each principle components
var = pca.explained_variance_ratio_
var
# Out:
# array([1.21150694e-01, 1.19694490e-01, 1.17993006e-01, 1.15048270e-01,
#        1.12529733e-01, 6.26582556e-02, 6.05756476e-02, 5.89048191e-02,
#        5.83233854e-02, 5.74188436e-02, 5.66139091e-02, 5.62410996e-02,
#        2.66421050e-03, 1.64843697e-04, 1.83040851e-05, 4.30359006e-07,
#        5.82039466e-08])

# %%
# Calculate the cumulative variance
var_net = np.cumsum(np.round(var,decimals=4)*100)
var_net
# Out:
# array([ 12.12,  24.09,  35.89,  47.39,  58.64,  64.91,  70.97,  76.86,
#         82.69,  88.43,  94.09,  99.71,  99.98, 100.  , 100.  , 100.  ,
#        100.  ])

# %%
# Plotting the variance of each component
plt.plot(var_net,color="blue")

# %%
pca_df = pd.DataFrame(pca_values)

# Reset the indexes of pca_df and df1
pca_df.reset_index(drop=True, inplace=True)
df_clean.reset_index(drop=True, inplace=True)

# %%
# Concatenate the reset data frames
final_data = pd.concat([pca_df.iloc[:, 0:11],df_clean['churn']], axis=1)

final_data.columns= list(df_clean.columns[0:11])+['churn']

# %%
final_data
# Out:
#       account_length  voice_plan  voice_messages  international_plan  \
# 0          -1.488389   -1.677699        1.901890           -2.084772
# 1           0.979828    0.586649        1.905338           -2.348489
# 2          -1.182075   -0.411782       -2.597033           -1.769787
# 3          -0.652339    0.725081       -1.337881           -0.208551
# 4          -1.590532   -1.031797        0.539859            1.128753
# ...              ...         ...             ...                 ...
# 4316       -0.576445   -0.776055       -1.413705            2.228380
# 4317        2.102421    0.071159        0.603057           -0.848559
# 4318        1.016787    1.691135       -0.593176           -0.937890
# 4319       -1.405156    0.782092        0.110264            0.156656
# 4320        2.195564   -1.692580        1.629859            1.540187
#
#       international_mins  international_calls  international_charge  day_mins  \
# ...

# %%
final_data['churn'].value_counts()
# Out:
# 0    3807
# 1     514
# Name: churn, dtype: int64

# %% [markdown]
# ## Scaling Numerical Feature

# %%
# Normalizing the dataframe input features
from sklearn.preprocessing import MinMaxScaler
minmax = final_data.iloc[:,:11]
minmax = MinMaxScaler().fit_transform(minmax)
minmax = pd.DataFrame(minmax,columns=list(df_clean.columns[0:11]))
final_data = pd.concat([minmax,final_data['churn']],axis=1)
final_data
# Out:
#       account_length  voice_plan  voice_messages  international_plan  \
# 0           0.347247    0.313076        0.698034            0.302653
# 1           0.585521    0.551404        0.698406            0.278199
# 2           0.376818    0.446317        0.213484            0.331860
# 3           0.427957    0.565974        0.349099            0.476626
# 4           0.337386    0.381059        0.551339            0.600627
# ...              ...         ...             ...                 ...
# 4316        0.435283    0.407976        0.340932            0.702591
# 4317        0.693892    0.497148        0.558145            0.417281
# 4318        0.589089    0.667654        0.429306            0.408997
# 4319        0.355282    0.571975        0.505070            0.510489
# 4320        0.702884    0.311510        0.668736            0.638778
#
#       international_mins  international_calls  international_charge  day_mins  \
# ...

# %% [markdown]
# ## Model Building Using Feature Importance Feature selection method

# %%
#Feature & Target Variables
X_1 = Final_df_fi.iloc[:, :9]
Y_1 = Final_df_fi['churn']

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X_1, Y_1, test_size= 0.3, random_state=10)

# %%
lr0 = LogisticRegression(class_weight='balanced')
lr0.fit(Xtrain,Ytrain)
# Train model 
y_pred_lr0_train = lr0.predict(Xtrain)
acc_lr0_train = accuracy_score(y_pred_lr0_train,Ytrain)
print('Training Accuracy:',acc_lr0_train*100)
# Test Model
y_pred_lr0_test = lr0.predict(Xtest)
acc_lr0_test = accuracy_score(y_pred_lr0_test,Ytest)
print('Testing Accuracy:',acc_lr0_test*100)
print('\n')
print(classification_report(y_pred_lr0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_lr0_test))
# Out:
# Training Accuracy: 75.56216931216932
# Testing Accuracy: 77.1781033153431
#
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.97      0.86       933
#            1       0.77      0.27      0.40       364
#
#     accuracy                           0.77      1297
#    macro avg       0.77      0.62      0.63      1297
# weighted avg       0.77      0.77      0.73      1297
#
#
#
# [[904 267]
#  [ 29  97]]

# %%
from sklearn.metrics import roc_curve,roc_auc_score

lr0 = LogisticRegression()
lr0.fit(Xtrain,Ytrain)

# Calculate predicted probabilities
y_prob_lr0_train = lr0.predict_proba(Xtrain)[:,1]
y_prob_lr0_test = lr0.predict_proba(Xtest)[:,1]

# Compute AUC and ROC curve for training set
fpr_train,tpr_train, thresholds_train = roc_curve(Ytrain,y_prob_lr0_train)
auc_train = roc_auc_score(Ytrain,y_prob_lr0_train)

# Compute AUC and ROC curve for test set
fpr_test,tpr_test, thresholds_test = roc_curve(Ytest,y_prob_lr0_test)
auc_test = roc_auc_score(Ytest,y_prob_lr0_test)

# plot the Roc Curve
plt.plot(fpr_train,tpr_train,label='Train ROC Curve (AUC = %0.2f)'% auc_train)
plt.plot(fpr_test,tpr_test,label='Test ROC Curve (AUC = %0.2f)'% auc_test)
plt.plot([0,1],[0,1],'k--') # Dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %%
nb0 = MultinomialNB()
nb0.fit(Xtrain,Ytrain)
# Train model 
y_pred_nb0_train = nb0.predict(Xtrain)
acc_nb0_train = accuracy_score(y_pred_nb0_train,Ytrain)
print('Training Accuracy:',acc_nb0_train*100)
# Test Model
y_pred_nb0_test = nb0.predict(Xtest)
acc_nb0_test = accuracy_score(y_pred_nb0_test,Ytest)
print('Testing Accuracy:',acc_nb0_test*100)
print('\n')
print(classification_report(y_pred_nb0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_nb0_test))
# Out:
# Training Accuracy: 84.32539682539682
# Testing Accuracy: 88.28064764841943
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1227
#            1       0.17      0.31      0.22        70
#
#     accuracy                           0.88      1297
#    macro avg       0.57      0.61      0.58      1297
# weighted avg       0.92      0.88      0.90      1297
#
#
#
# [[1123   48]
#  [ 104   22]]

# %%
dt0 = DecisionTreeClassifier(criterion='entropy',max_depth=3,class_weight='balanced')
dt0.fit(Xtrain,Ytrain)
# Train model 
y_pred_dt0_train = dt0.predict(Xtrain)
acc_dt0_train = accuracy_score(y_pred_dt0_train,Ytrain)
print('Training Accuracy:',acc_dt0_train*100)
# Test Model
y_pred_dt0_test = dt0.predict(Xtest)
acc_dt0_test = accuracy_score(y_pred_dt0_test,Ytest)
print('Testing Accuracy:',acc_dt0_test*100)
print('\n')
print(classification_report(y_pred_dt0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_dt0_test))
# Out:
# Training Accuracy: 81.67989417989418
# Testing Accuracy: 82.49807247494218
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90       994
#            1       0.80      0.33      0.47       303
#
#     accuracy                           0.82      1297
#    macro avg       0.81      0.65      0.68      1297
# weighted avg       0.82      0.82      0.80      1297
#
#
#
# [[969 202]
#  [ 25 101]]

# %%
dt0 = DecisionTreeClassifier(criterion='entropy', max_depth=3, class_weight='balanced')
dt0.fit(Xtrain, Ytrain)

y_pred_dt0_train = dt0.predict(Xtrain)
y_pred_dt0_test = dt0.predict(Xtest)

y_prob_dt0_train = dt0.predict_proba(Xtrain)[:, 1]
y_prob_dt0_test = dt0.predict_proba(Xtest)[:, 1]

fpr_train, tpr_train, thresholds_train = roc_curve(Ytrain, y_prob_dt0_train)
fpr_test, tpr_test, thresholds_test = roc_curve(Ytest, y_prob_dt0_test)

auc_train = roc_auc_score(Ytrain, y_prob_dt0_train)
auc_test = roc_auc_score(Ytest, y_prob_dt0_test)

plt.plot(fpr_train, tpr_train, label='Train ROC curve (AUC = %0.2f)' % auc_train)
plt.plot(fpr_test, tpr_test, label='Test ROC curve (AUC = %0.2f)' % auc_test)
plt.plot([0, 1], [0, 1], 'k--')  # dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %%
rf0 = RandomForestClassifier(random_state=0,class_weight='balanced')
rf0.fit(Xtrain,Ytrain)
# Train model 
y_pred_rf0_train = rf0.predict(Xtrain)
acc_rf0_train = accuracy_score(y_pred_rf0_train,Ytrain)
print('Training Accuracy:',acc_rf0_train*100)
# Test Model
y_pred_rf0_test = rf0.predict(Xtest)
acc_rf0_test = accuracy_score(y_pred_rf0_test,Ytest)
print('Testing Accuracy:',acc_rf0_test*100)
print('\n')
print(classification_report(y_pred_rf0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_rf0_test))
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 95.37393986121819
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      1193
#            1       0.67      0.82      0.74       104
#
#     accuracy                           0.95      1297
#    macro avg       0.83      0.89      0.86      1297
# weighted avg       0.96      0.95      0.96      1297
#
#
#
# [[1152   19]
#  [  41   85]]

# %%
rf0 = RandomForestClassifier(random_state=0, class_weight='balanced')
rf0.fit(Xtrain, Ytrain)

y_pred_rf0_train = rf0.predict(Xtrain)
y_pred_rf0_test = rf0.predict(Xtest)

y_prob_rf0_train = rf0.predict_proba(Xtrain)[:, 1]
y_prob_rf0_test = rf0.predict_proba(Xtest)[:, 1]

fpr_train, tpr_train, thresholds_train = roc_curve(Ytrain, y_prob_rf0_train)
fpr_test, tpr_test, thresholds_test = roc_curve(Ytest, y_prob_rf0_test)

auc_train = roc_auc_score(Ytrain, y_prob_rf0_train)
auc_test = roc_auc_score(Ytest, y_prob_rf0_test)

plt.plot(fpr_train, tpr_train, label='Train ROC curve (AUC = %0.2f)' % auc_train)
plt.plot(fpr_test, tpr_test, label='Test ROC curve (AUC = %0.2f)' % auc_test)
plt.plot([0, 1], [0, 1], 'k--')  # dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %%
svc0 = SVC(class_weight='balanced')
svc0.fit(Xtrain,Ytrain)
# Train model 
y_pred_svc0_train = svc0.predict(Xtrain)
acc_svc0_train = accuracy_score(y_pred_svc0_train,Ytrain)
print('Training Accuracy:',acc_svc0_train*100)
# Test Model
y_pred_svc0_test = svc0.predict(Xtest)
acc_svc0_test = accuracy_score(y_pred_svc0_test,Ytest)
print('Testing Accuracy:',acc_svc0_test*100)
print('\n')
print(classification_report(y_pred_svc0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_svc0_test))
# Out:
# Training Accuracy: 82.10978835978835
# Testing Accuracy: 83.34618350038551
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      1115
#            1       0.37      0.25      0.30       182
#
#     accuracy                           0.83      1297
#    macro avg       0.62      0.59      0.60      1297
# weighted avg       0.81      0.83      0.82      1297
#
#
#
# [[1035  136]
#  [  80   46]]

# %%
svc0 = SVC(class_weight='balanced')
svc0.fit(Xtrain, Ytrain)

y_pred_svc0_train = svc0.predict(Xtrain)
y_pred_svc0_test = svc0.predict(Xtest)

y_prob_svc0_train = svc0.decision_function(Xtrain)
y_prob_svc0_test = svc0.decision_function(Xtest)

fpr_train, tpr_train, thresholds_train = roc_curve(Ytrain, y_prob_svc0_train)
fpr_test, tpr_test, thresholds_test = roc_curve(Ytest, y_prob_svc0_test)

auc_train = roc_auc_score(Ytrain, y_prob_svc0_train)
auc_test = roc_auc_score(Ytest, y_prob_svc0_test)

plt.plot(fpr_train, tpr_train, label='Train ROC curve (AUC = %0.2f)' % auc_train)
plt.plot(fpr_test, tpr_test, label='Test ROC curve (AUC = %0.2f)' % auc_test)
plt.plot([0, 1], [0, 1], 'k--')  # dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb0 = GradientBoostingClassifier(n_estimators=100,learning_rate=1.0,max_depth=1,random_state=0)
gb0.fit(Xtrain,Ytrain)
# Train model 
y_pred_gb0_train = gb0.predict(Xtrain)
acc_gb0_train = accuracy_score(y_pred_gb0_train,Ytrain)
print('Training Accuracy:',acc_gb0_train*100)
# Test Model
y_pred_gb0_test = gb0.predict(Xtest)
acc_gb0_test = accuracy_score(y_pred_gb0_test,Ytest)
print('Testing Accuracy:',acc_gb0_test*100)
print('\n')
print(classification_report(y_pred_gb0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_gb0_test))
# Out:
# Training Accuracy: 90.67460317460318
# Testing Accuracy: 90.43947571318427
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      1209
#            1       0.36      0.51      0.42        88
#
#     accuracy                           0.90      1297
#    macro avg       0.66      0.72      0.68      1297
# weighted avg       0.92      0.90      0.91      1297
#
#
#
# [[1128   43]
#  [  81   45]]

# %%
gb0 = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)
gb0.fit(Xtrain, Ytrain)

y_pred_gb0_train = gb0.predict(Xtrain)
y_pred_gb0_test = gb0.predict(Xtest)

y_prob_gb0_train = gb0.predict_proba(Xtrain)[:, 1]
y_prob_gb0_test = gb0.predict_proba(Xtest)[:, 1]

fpr_train, tpr_train, thresholds_train = roc_curve(Ytrain, y_prob_gb0_train)
fpr_test, tpr_test, thresholds_test = roc_curve(Ytest, y_prob_gb0_test)

auc_train = roc_auc_score(Ytrain, y_prob_gb0_train)
auc_test = roc_auc_score(Ytest, y_prob_gb0_test)

plt.plot(fpr_train, tpr_train, label='Train ROC curve (AUC = %0.2f)' % auc_train)
plt.plot(fpr_test, tpr_test, label='Test ROC curve (AUC = %0.2f)' % auc_test)
plt.plot([0, 1], [0, 1], 'k--')  # dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %%
from sklearn.ensemble import AdaBoostClassifier
ab0 = AdaBoostClassifier(n_estimators=100,learning_rate=1.0,random_state=0)
ab0.fit(Xtrain,Ytrain)
# Train model 
y_pred_ab0_train = ab0.predict(Xtrain)
acc_ab0_train = accuracy_score(y_pred_ab0_train,Ytrain)
print('Training Accuracy:',acc_ab0_train*100)
# Test Model
y_pred_ab0_test = ab0.predict(Xtest)
acc_ab0_test = accuracy_score(y_pred_ab0_test,Ytest)
print('Testing Accuracy:',acc_ab0_test*100)
print('\n')
print(classification_report(y_pred_ab0_test,Ytest))
print('\n')
print(confusion_matrix(Ytest,y_pred_ab0_test))
# Out:
# Training Accuracy: 89.91402116402116
# Testing Accuracy: 90.5165767154973
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      1220
#            1       0.32      0.52      0.39        77
#
#     accuracy                           0.91      1297
#    macro avg       0.64      0.72      0.67      1297
# weighted avg       0.93      0.91      0.92      1297
#
#
#
# [[1134   37]
#  [  86   40]]

# %%
ab0 = AdaBoostClassifier(n_estimators=100, learning_rate=1.0, random_state=0)
ab0.fit(Xtrain, Ytrain)

y_pred_ab0_train = ab0.predict(Xtrain)
y_pred_ab0_test = ab0.predict(Xtest)

y_prob_ab0_train = ab0.predict_proba(Xtrain)[:, 1]
y_prob_ab0_test = ab0.predict_proba(Xtest)[:, 1]

fpr_train, tpr_train, thresholds_train = roc_curve(Ytrain, y_prob_ab0_train)
fpr_test, tpr_test, thresholds_test = roc_curve(Ytest, y_prob_ab0_test)

auc_train = roc_auc_score(Ytrain, y_prob_ab0_train)
auc_test = roc_auc_score(Ytest, y_prob_ab0_test)

plt.plot(fpr_train, tpr_train, label='Train ROC curve (AUC = %0.2f)' % auc_train)
plt.plot(fpr_test, tpr_test, label='Test ROC curve (AUC = %0.2f)' % auc_test)
plt.plot([0, 1], [0, 1], 'k--')  # dashed diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# %% [markdown]
# ##  Balancing The Data

# %%
# !pip install imbalanced-learn

# %%
print(final_data['churn'].value_counts())

sns.countplot(x='churn',data=final_data)
# Out:
# 0    3807
# 1     514
# Name: churn, dtype: int64
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %%
# Oversampling Minor class
from imblearn.over_sampling import SMOTE

# %%
x2 = final_data.iloc[:,:11]
y2 = final_data['churn']
# Implementing Oversampling for Handling imbalanced
smk = SMOTE(sampling_strategy='minority',random_state=0)
x_res , y_res = smk.fit_resample(x2,y2)
final_bal = pd.concat([pd.DataFrame(x_res),pd.DataFrame(y_res)],axis=1)
final_bal
# Out:
#       account_length  voice_plan  voice_messages  international_plan  \
# 0           0.347247    0.313076        0.698034            0.302653
# 1           0.585521    0.551404        0.698406            0.278199
# 2           0.376818    0.446317        0.213484            0.331860
# 3           0.427957    0.565974        0.349099            0.476626
# 4           0.337386    0.381059        0.551339            0.600627
# ...              ...         ...             ...                 ...
# 7609        0.510452    0.252760        0.511977            0.463239
# 7610        0.605804    0.655897        0.615244            0.549613
# 7611        0.433546    0.607411        0.444136            0.636083
# 7612        0.601991    0.573822        0.427807            0.621696
# 7613        0.349027    0.314231        0.499266            0.480297
#
#       international_mins  international_calls  international_charge  day_mins  \
# ...

# %%
print(final_bal['churn'].value_counts())
print('\n')

sns.countplot(x='churn',data=final_bal)
# Out:
# 0    3807
# 1    3807
# Name: churn, dtype: int64
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# # Model Building : Balanced Processed data Post Feature Engineering

# %%
# Feature And target variable
X1 = final_bal.iloc[:,:11]
Y1 = final_bal['churn']

X1_train,X1_test,Y1_train,Y1_test = train_test_split(X1,Y1,test_size=0.3,random_state=10)

# %% [markdown]
# ### Model [1] : Logistic Regression

# %%
lr1 = LogisticRegression()
lr1.fit(X1_train,Y1_train)
# Train model 
y_pred_lr1_train = lr1.predict(X1_train)
acc_lr1_train = accuracy_score(y_pred_lr1_train,Y1_train)
print('Training Accuracy:',acc_lr1_train*100)
# Test Model
y_pred_lr1_test = lr1.predict(X1_test)
acc_lr1_test = accuracy_score(y_pred_lr1_test,Y1_test)
print('Testing Accuracy:',acc_lr1_test*100)
print('\n')
print(classification_report(y_pred_lr1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_lr1_test))
# Out:
# Training Accuracy: 76.14937136423345
# Testing Accuracy: 75.84245076586433
#
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      1107
#            1       0.78      0.74      0.76      1178
#
#     accuracy                           0.76      2285
#    macro avg       0.76      0.76      0.76      2285
# weighted avg       0.76      0.76      0.76      2285
#
#
#
# [[860 305]
#  [247 873]]

# %% [markdown]
# ### Model [2] : Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X1_train,Y1_train)
# Train model 
y_pred_nb1_train = nb.predict(X1_train)
acc_nb1_train = accuracy_score(y_pred_nb1_train,Y1_train)
print('Training Accuracy:',acc_nb1_train*100)
# Test Model
y_pred_nb1_test = nb.predict(X1_test)
acc_nb1_test = accuracy_score(y_pred_nb1_test,Y1_test)
print('Testing Accuracy:',acc_nb1_test*100)
print('\n')
print(classification_report(y_pred_nb1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_nb1_test))
# Out:
# Training Accuracy: 73.93507224620004
# Testing Accuracy: 72.42888402625822
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.69       899
#            1       0.84      0.68      0.75      1386
#
#     accuracy                           0.72      2285
#    macro avg       0.73      0.74      0.72      2285
# weighted avg       0.75      0.72      0.73      2285
#
#
#
# [[717 448]
#  [182 938]]

# %% [markdown]
# ### Model [3] : Decision Tree Classifier

# %%
dt = DecisionTreeClassifier(criterion='entropy',max_depth=3)
dt.fit(X1_train,Y1_train)
# Train model 
y_pred_dt1_train = dt.predict(X1_train)
acc_dt1_train = accuracy_score(y_pred_dt1_train,Y1_train)
print('Training Accuracy:',acc_dt1_train*100)
# Test Model
y_pred_dt1_test = dt.predict(X1_test)
acc_dt1_test = accuracy_score(y_pred_dt1_test,Y1_test)
print('Testing Accuracy:',acc_dt1_test*100)
print('\n')
print(classification_report(y_pred_dt1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_dt1_test))
# Out:
# Training Accuracy: 74.17902045411897
# Testing Accuracy: 73.21663019693653
#
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.80      0.71       925
#            1       0.83      0.69      0.75      1360
#
#     accuracy                           0.73      2285
#    macro avg       0.73      0.74      0.73      2285
# weighted avg       0.75      0.73      0.73      2285
#
#
#
# [[739 426]
#  [186 934]]

# %% [markdown]
# ### Model [4] : Random Forest

# %%
rf = RandomForestClassifier(random_state=0)
rf.fit(X1_train,Y1_train)
# Train model 
y_pred_rf1_train = rf.predict(X1_train)
acc_rf1_train = accuracy_score(y_pred_rf1_train,Y1_train)
print('Training Accuracy:',acc_rf1_train*100)
# Test Model
y_pred_rf1_test = rf.predict(X1_test)
acc_rf1_test = accuracy_score(y_pred_rf1_test,Y1_test)
print('Testing Accuracy:',acc_rf1_test*100)
print('\n')
print(classification_report(y_pred_rf1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_rf1_test))
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 92.95404814004377
#
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1146
#            1       0.94      0.92      0.93      1139
#
#     accuracy                           0.93      2285
#    macro avg       0.93      0.93      0.93      2285
# weighted avg       0.93      0.93      0.93      2285
#
#
#
# [[1075   90]
#  [  71 1049]]

# %% [markdown]
# ### Model[5] : Support Vector Classifier

# %%
svc = SVC()
svc.fit(X1_train,Y1_train)
# Train model 
y_pred_svc1_train = svc.predict(X1_train)
acc_svc1_train = accuracy_score(y_pred_svc1_train,Y1_train)
print('Training Accuracy:',acc_svc1_train*100)
# Test Model
y_pred_svc1_test = svc.predict(X1_test)
acc_svc1_test = accuracy_score(y_pred_svc1_test,Y1_test)
print('Testing Accuracy:',acc_svc1_test*100)
print('\n')
print(classification_report(y_pred_svc1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_svc1_test))
# Out:
# Training Accuracy: 90.6736723587915
# Testing Accuracy: 88.88402625820568
#
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89      1207
#            1       0.87      0.90      0.88      1078
#
#     accuracy                           0.89      2285
#    macro avg       0.89      0.89      0.89      2285
# weighted avg       0.89      0.89      0.89      2285
#
#
#
# [[1059  106]
#  [ 148  972]]

# %% [markdown]
# ### Model [6] : Gradient Boosting

# %%
gb = GradientBoostingClassifier(n_estimators=100,learning_rate=1.0,max_depth=1,random_state=0)
gb.fit(X1_train,Y1_train)
# Train model 
y_pred_gb1_train = gb.predict(X1_train)
acc_gb1_train = accuracy_score(y_pred_gb1_train,Y1_train)
print('Training Accuracy:',acc_gb1_train*100)
# Test Model
y_pred_gb1_test = gb.predict(X1_test)
acc_gb1_test = accuracy_score(y_pred_gb1_test,Y1_test)
print('Testing Accuracy:',acc_gb1_test*100)
print('\n')
print(classification_report(y_pred_gb1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_gb1_test))
# Out:
# Training Accuracy: 83.84312253706136
# Testing Accuracy: 81.53172866520788
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      1187
#            1       0.80      0.82      0.81      1098
#
#     accuracy                           0.82      2285
#    macro avg       0.82      0.82      0.82      2285
# weighted avg       0.82      0.82      0.82      2285
#
#
#
# [[965 200]
#  [222 898]]

# %% [markdown]
# ### Model [7] : AdaBoost Classifier

# %%
ab = AdaBoostClassifier(n_estimators=100,learning_rate=1.0,random_state=0)
ab.fit(X1_train,Y1_train)
# Train model 
y_pred_ab1_train = ab.predict(X1_train)
acc_ab1_train = accuracy_score(y_pred_ab1_train,Y1_train)
print('Training Accuracy:',acc_ab1_train*100)
# Test Model
y_pred_ab1_test = ab.predict(X1_test)
acc_ab1_test = accuracy_score(y_pred_ab1_test,Y1_test)
print('Testing Accuracy:',acc_ab1_test*100)
print('\n')
print(classification_report(y_pred_ab1_test,Y1_test))
print('\n')
print(confusion_matrix(Y1_test,y_pred_ab1_test))
# Out:
# Training Accuracy: 82.94239069243761
# Testing Accuracy: 81.00656455142231
#
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81      1173
#            1       0.80      0.81      0.81      1112
#
#     accuracy                           0.81      2285
#    macro avg       0.81      0.81      0.81      2285
# weighted avg       0.81      0.81      0.81      2285
#
#
#
# [[952 213]
#  [221 899]]

# %%
balance_process = {'Model':['Logistic Regression','Naive bayes','Decision Tree','Random Forest','Support Vector Classifier',
                             'Gradient Boosting','Adaboost Classifier'],
                    'Training Accuracy':[acc_lr1_train , acc_nb1_train , acc_dt1_train , acc_rf1_train , acc_svc1_train , acc_gb1_train ,
                                        acc_ab1_train],
                    'Testing Accuracy':[acc_lr1_test , acc_nb1_test , acc_dt1_test , acc_rf1_test , acc_svc1_test , acc_gb1_test ,
                                       acc_ab1_test ]}
result1 = pd.DataFrame(balance_process)
result1 = result1.sort_values(by='Testing Accuracy',ascending=False,ignore_index=True)
result1
# Out:
#                        Model  Training Accuracy  Testing Accuracy
# 0              Random Forest           1.000000          0.929540
# 1  Support Vector Classifier           0.906737          0.888840
# 2          Gradient Boosting           0.838431          0.815317
# 3        Adaboost Classifier           0.829424          0.810066
# 4        Logistic Regression           0.761494          0.758425
# 5              Decision Tree           0.741790          0.732166
# 6                Naive bayes           0.739351          0.724289

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Model',y='Testing Accuracy',data=result1)
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Testing Accuracy'>
